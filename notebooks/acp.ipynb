# %%
import pandas as pd

# %%
fao_statistics = pd.read_csv("../export/final_data_2020.csv", index_col="pays")
fao_statistics
# Out:
#                        code_groupe_de_pays groupe_de_pays  country_code  \
# pays
# Côte d'Ivoire                         5100        Afrique           107
# Kenya                                 5100        Afrique           114
# Lesotho                               5100        Afrique           122
# Libéria                               5100        Afrique           123
# Libye                                 5100        Afrique           124
# ...                                    ...            ...           ...
# Îles Wallis-et-Futuna                 5000          Monde           243
# Samoa                                 5000          Monde           244
# Îles Cook                             5000          Monde            47
# Samoa américaines                     5000          Monde             5
# Polynésie française                   5000          Monde            70
#
#                        population_totale  \
# pays
# Côte d'Ivoire                 28915449.0
# Kenya                         52217334.0
# Lesotho                        2235727.0
# Libéria                        5149463.0
# Libye                          7045399.0
# ...                                  ...
# Îles Wallis-et-Futuna            11616.0
# Samoa                           211944.0
# Îles Cook                        15643.0
# Samoa américaines                49761.0
# Polynésie française             279209.0
#
#                        besoins_energetiques_alimentaires_moyens_(kcal/personne/jour)  \
# pays
# Côte d'Ivoire                                                     2233.0
# Kenya                                                             2254.0
# Lesotho                                                           2299.0
# Libéria                                                           2213.0
# Libye                                                             2384.0
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                             2335.0
# Îles Cook                                                            0.0
# Samoa américaines                                                    0.0
# Polynésie française                                               2440.0
#
#                        densite_du_reseau_ferroviaire_(pour_100_km_carres_de_surface_totale_du_pays)  \
# pays
# Côte d'Ivoire                                                        0.2
# Kenya                                                                0.0
# Lesotho                                                              0.0
# Libéria                                                              0.0
# Libye                                                                0.0
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                                0.0
# Îles Cook                                                            0.0
# Samoa américaines                                                    0.0
# Polynésie française                                                  0.0
#
#                        pib_par_habitant,_($_ppa_internationaux_constants_de_2017)  \
# pays
# Côte d'Ivoire                                               6.161200e+09
# Kenya                                                       5.079900e+09
# Lesotho                                                     2.440900e+09
# Libéria                                                     1.513800e+09
# Libye                                                       1.166060e+10
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                       6.689700e+09
# Îles Cook                                                   0.000000e+00
# Samoa américaines                                           0.000000e+00
# Polynésie française                                         0.000000e+00
#
#                        stabilite_politique_et_absence_de_violence/terrorisme_(indice)  \
# pays
# Côte d'Ivoire                                                      -1.03
# Kenya                                                              -1.01
# Lesotho                                                            -0.25
# Libéria                                                            -0.31
# Libye                                                              -2.46
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                               1.15
# Îles Cook                                                           0.00
# Samoa américaines                                                   1.09
# Polynésie française                                                 0.00
#
#                        taux_de_dependance_a_l'egard_des_importations_cerealieres_(%)_(moyenne_sur_3_ans)  \
# pays
# Côte d'Ivoire                                                       48.4
# Kenya                                                               47.8
# Lesotho                                                            100.0
# Libéria                                                             71.8
# Libye                                                               92.5
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                                0.0
# Îles Cook                                                            0.0
# Samoa américaines                                                    0.0
# Polynésie française                                                  0.0
#
#                        valeur_des_importations_alimentaires_par_rapport_aux_exportations_totales_de_marchandises_(%)_(moyenne_sur_3_ans)  \
# pays
# Côte d'Ivoire                                                       12.0
# Kenya                                                               42.0
# Lesotho                                                             30.0
# Libéria                                                             60.0
# Libye                                                               16.0
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                              218.0
# Îles Cook                                                          176.0
# Samoa américaines                                                    0.0
# Polynésie française                                                326.0
#
#                        ...  \
# pays                   ...
# Côte d'Ivoire          ...
# Kenya                  ...
# Lesotho                ...
# Libéria                ...
# Libye                  ...
# ...                    ...
# Îles Wallis-et-Futuna  ...
# Samoa                  ...
# Îles Cook              ...
# Samoa américaines      ...
# Polynésie française    ...
#
#                        valeur_des_importations_-_quantite_periode_de_reference  \
# pays
# Côte d'Ivoire                                                  1432922.0
# Kenya                                                          2044179.0
# Lesotho                                                         282993.0
# Libéria                                                         309123.0
# Libye                                                          2956348.0
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                            82663.0
# Îles Cook                                                        27954.0
# Samoa américaines                                                    NaN
# Polynésie française                                             363838.0
#
#                        indicateur_emploi  \
# pays
# Côte d'Ivoire                        NaN
# Kenya                                NaN
# Lesotho                              NaN
# Libéria                              NaN
# Libye                                NaN
# ...                                  ...
# Îles Wallis-et-Futuna                NaN
# Samoa                                NaN
# Îles Cook                            NaN
# Samoa américaines                    NaN
# Polynésie française                  NaN
#
#                        production_brute_2014-2016_(millier_int$)  reserves  \
# pays
# Côte d'Ivoire                                           142705.0   89511.0
# Kenya                                                   132879.0   57178.0
# Lesotho                                                      2.0     471.0
# Libéria                                                  26665.0    8031.0
# Libye                                                   249303.0   36550.0
# ...                                                          ...       ...
# Îles Wallis-et-Futuna                                        NaN       NaN
# Samoa                                                      625.0     386.0
# Îles Cook                                                   80.0      34.0
# Samoa américaines                                            NaN       NaN
# Polynésie française                                       1100.0     325.0
#
#                        disponibilite_interieure  exportations_-_quantite  \
# pays
# Côte d'Ivoire                              72.0                      0.0
# Kenya                                      69.0                      0.0
# Lesotho                                     4.0                      NaN
# Libéria                                    56.0                      0.0
# Libye                                     223.0                      NaN
# ...                                         ...                      ...
# Îles Wallis-et-Futuna                       NaN                      NaN
# Samoa                                      16.0                      NaN
# Îles Cook                                   NaN                      NaN
# Samoa américaines                           NaN                      NaN
# Polynésie française                        17.0                      NaN
#
#                        importations_-_quantite  nourriture  production  \
# pays
# Côte d'Ivoire                              1.0        72.0        71.0
# Kenya                                      1.0        69.0        69.0
# Lesotho                                    3.0         4.0         1.0
# Libéria                                   42.0        56.0        15.0
# Libye                                     96.0       223.0       127.0
# ...                                        ...         ...         ...
# Îles Wallis-et-Futuna                      NaN         NaN         NaN
# Samoa                                     16.0        16.0         0.0
# Îles Cook                                  NaN         NaN         NaN
# Samoa américaines                          NaN         NaN         NaN
# Polynésie française                       17.0        14.0         1.0
#
#                        variation_de_stock
# pays
# Côte d'Ivoire                         0.0
# Kenya                                 1.0
# Lesotho                               0.0
# Libéria                               0.0
# Libye                                 0.0
# ...                                   ...
# Îles Wallis-et-Futuna                 NaN
# Samoa                                 0.0
# Îles Cook                             NaN
# Samoa américaines                     NaN
# Polynésie française                   1.0
#
# [236 rows x 24 columns]

# %%
fao_statistics.columns
# Out:
# Index(['code_groupe_de_pays', 'groupe_de_pays', 'country_code',
#        'population_totale',
#        'besoins_energetiques_alimentaires_moyens_(kcal/personne/jour)',
#        'densite_du_reseau_ferroviaire_(pour_100_km_carres_de_surface_totale_du_pays)',
#        'pib_par_habitant,_($_ppa_internationaux_constants_de_2017)',
#        'stabilite_politique_et_absence_de_violence/terrorisme_(indice)',
#        'taux_de_dependance_a_l'egard_des_importations_cerealieres_(%)_(moyenne_sur_3_ans)',
#        'valeur_des_importations_alimentaires_par_rapport_aux_exportations_totales_de_marchandises_(%)_(moyenne_sur_3_ans)',
#        'variabilite_des_disponibilites_alimentaires_par_habitant_(kcal/personne/jour)',
#        'valeur_des_exportations_-_prix_periode_de_reference',
#        'valeur_des_exportations_-_quantite_periode_de_reference',
#        'valeur_des_importations_-_prix_periode_de_reference',
#        'valeur_des_importations_-_quantite_periode_de_reference',
#        'indicateur_emploi', 'production_brute_2014-2016_(millier_int$)',
#        'reserves', 'disponibilite_interieure', 'exportations_-_quantite',
#        'importations_-_quantite', 'nourriture', 'production',
#        'variation_de_stock'],
#       dtype='object')

# %% [markdown]
# fao_statistics = fao_statistics.drop(columns=['code_groupe_de_pays', 'groupe_de_pays', 'code_groupe_m49', 'code_pays',
# 'code_m49', 'code_iso2', 'code_iso3', 'country_code', 'zone', 'zone_secu',
# 'zone_indices', 'femmes', 'hommes', 'population_rurale', 'population_urbaine'])

# %%
fao_statistics
# Out:
#                        code_groupe_de_pays groupe_de_pays  country_code  \
# pays
# Côte d'Ivoire                         5100        Afrique           107
# Kenya                                 5100        Afrique           114
# Lesotho                               5100        Afrique           122
# Libéria                               5100        Afrique           123
# Libye                                 5100        Afrique           124
# ...                                    ...            ...           ...
# Îles Wallis-et-Futuna                 5000          Monde           243
# Samoa                                 5000          Monde           244
# Îles Cook                             5000          Monde            47
# Samoa américaines                     5000          Monde             5
# Polynésie française                   5000          Monde            70
#
#                        population_totale  \
# pays
# Côte d'Ivoire                 28915449.0
# Kenya                         52217334.0
# Lesotho                        2235727.0
# Libéria                        5149463.0
# Libye                          7045399.0
# ...                                  ...
# Îles Wallis-et-Futuna            11616.0
# Samoa                           211944.0
# Îles Cook                        15643.0
# Samoa américaines                49761.0
# Polynésie française             279209.0
#
#                        besoins_energetiques_alimentaires_moyens_(kcal/personne/jour)  \
# pays
# Côte d'Ivoire                                                     2233.0
# Kenya                                                             2254.0
# Lesotho                                                           2299.0
# Libéria                                                           2213.0
# Libye                                                             2384.0
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                             2335.0
# Îles Cook                                                            0.0
# Samoa américaines                                                    0.0
# Polynésie française                                               2440.0
#
#                        densite_du_reseau_ferroviaire_(pour_100_km_carres_de_surface_totale_du_pays)  \
# pays
# Côte d'Ivoire                                                        0.2
# Kenya                                                                0.0
# Lesotho                                                              0.0
# Libéria                                                              0.0
# Libye                                                                0.0
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                                0.0
# Îles Cook                                                            0.0
# Samoa américaines                                                    0.0
# Polynésie française                                                  0.0
#
#                        pib_par_habitant,_($_ppa_internationaux_constants_de_2017)  \
# pays
# Côte d'Ivoire                                               6.161200e+09
# Kenya                                                       5.079900e+09
# Lesotho                                                     2.440900e+09
# Libéria                                                     1.513800e+09
# Libye                                                       1.166060e+10
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                       6.689700e+09
# Îles Cook                                                   0.000000e+00
# Samoa américaines                                           0.000000e+00
# Polynésie française                                         0.000000e+00
#
#                        stabilite_politique_et_absence_de_violence/terrorisme_(indice)  \
# pays
# Côte d'Ivoire                                                      -1.03
# Kenya                                                              -1.01
# Lesotho                                                            -0.25
# Libéria                                                            -0.31
# Libye                                                              -2.46
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                               1.15
# Îles Cook                                                           0.00
# Samoa américaines                                                   1.09
# Polynésie française                                                 0.00
#
#                        taux_de_dependance_a_l'egard_des_importations_cerealieres_(%)_(moyenne_sur_3_ans)  \
# pays
# Côte d'Ivoire                                                       48.4
# Kenya                                                               47.8
# Lesotho                                                            100.0
# Libéria                                                             71.8
# Libye                                                               92.5
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                                0.0
# Îles Cook                                                            0.0
# Samoa américaines                                                    0.0
# Polynésie française                                                  0.0
#
#                        valeur_des_importations_alimentaires_par_rapport_aux_exportations_totales_de_marchandises_(%)_(moyenne_sur_3_ans)  \
# pays
# Côte d'Ivoire                                                       12.0
# Kenya                                                               42.0
# Lesotho                                                             30.0
# Libéria                                                             60.0
# Libye                                                               16.0
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                              218.0
# Îles Cook                                                          176.0
# Samoa américaines                                                    0.0
# Polynésie française                                                326.0
#
#                        ...  \
# pays                   ...
# Côte d'Ivoire          ...
# Kenya                  ...
# Lesotho                ...
# Libéria                ...
# Libye                  ...
# ...                    ...
# Îles Wallis-et-Futuna  ...
# Samoa                  ...
# Îles Cook              ...
# Samoa américaines      ...
# Polynésie française    ...
#
#                        valeur_des_importations_-_quantite_periode_de_reference  \
# pays
# Côte d'Ivoire                                                  1432922.0
# Kenya                                                          2044179.0
# Lesotho                                                         282993.0
# Libéria                                                         309123.0
# Libye                                                          2956348.0
# ...                                                                  ...
# Îles Wallis-et-Futuna                                                NaN
# Samoa                                                            82663.0
# Îles Cook                                                        27954.0
# Samoa américaines                                                    NaN
# Polynésie française                                             363838.0
#
#                        indicateur_emploi  \
# pays
# Côte d'Ivoire                        NaN
# Kenya                                NaN
# Lesotho                              NaN
# Libéria                              NaN
# Libye                                NaN
# ...                                  ...
# Îles Wallis-et-Futuna                NaN
# Samoa                                NaN
# Îles Cook                            NaN
# Samoa américaines                    NaN
# Polynésie française                  NaN
#
#                        production_brute_2014-2016_(millier_int$)  reserves  \
# pays
# Côte d'Ivoire                                           142705.0   89511.0
# Kenya                                                   132879.0   57178.0
# Lesotho                                                      2.0     471.0
# Libéria                                                  26665.0    8031.0
# Libye                                                   249303.0   36550.0
# ...                                                          ...       ...
# Îles Wallis-et-Futuna                                        NaN       NaN
# Samoa                                                      625.0     386.0
# Îles Cook                                                   80.0      34.0
# Samoa américaines                                            NaN       NaN
# Polynésie française                                       1100.0     325.0
#
#                        disponibilite_interieure  exportations_-_quantite  \
# pays
# Côte d'Ivoire                              72.0                      0.0
# Kenya                                      69.0                      0.0
# Lesotho                                     4.0                      NaN
# Libéria                                    56.0                      0.0
# Libye                                     223.0                      NaN
# ...                                         ...                      ...
# Îles Wallis-et-Futuna                       NaN                      NaN
# Samoa                                      16.0                      NaN
# Îles Cook                                   NaN                      NaN
# Samoa américaines                           NaN                      NaN
# Polynésie française                        17.0                      NaN
#
#                        importations_-_quantite  nourriture  production  \
# pays
# Côte d'Ivoire                              1.0        72.0        71.0
# Kenya                                      1.0        69.0        69.0
# Lesotho                                    3.0         4.0         1.0
# Libéria                                   42.0        56.0        15.0
# Libye                                     96.0       223.0       127.0
# ...                                        ...         ...         ...
# Îles Wallis-et-Futuna                      NaN         NaN         NaN
# Samoa                                     16.0        16.0         0.0
# Îles Cook                                  NaN         NaN         NaN
# Samoa américaines                          NaN         NaN         NaN
# Polynésie française                       17.0        14.0         1.0
#
#                        variation_de_stock
# pays
# Côte d'Ivoire                         0.0
# Kenya                                 1.0
# Lesotho                               0.0
# Libéria                               0.0
# Libye                                 0.0
# ...                                   ...
# Îles Wallis-et-Futuna                 NaN
# Samoa                                 0.0
# Îles Cook                             NaN
# Samoa américaines                     NaN
# Polynésie française                   1.0
#
# [236 rows x 24 columns]
