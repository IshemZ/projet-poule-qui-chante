# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ### Processing dispo alimentaire 2017
# ---

# %%
#Importer le fichier en gardant toute les colonnes en string
dispo = pd.read_csv('../data/raw_data/DisponibiliteAlimentaire_2017.csv', sep=',', encoding='utf-8-sig', dtype=str)
dispo.head()
# Out:
#   Code Domaine                      Domaine Code zone         Zone  \
# 0          FBS  Nouveaux Bilans Alimentaire         2  Afghanistan
# 1          FBS  Nouveaux Bilans Alimentaire         2  Afghanistan
# 2          FBS  Nouveaux Bilans Alimentaire         2  Afghanistan
# 3          FBS  Nouveaux Bilans Alimentaire         2  Afghanistan
# 4          FBS  Nouveaux Bilans Alimentaire         2  Afghanistan
#
#   Code Élément                   Élément Code Produit          Produit  \
# 0         5511                Production         2511  Blé et produits
# 1         5611   Importations - Quantité         2511  Blé et produits
# 2         5072        Variation de stock         2511  Blé et produits
# 3         5911   Exportations - Quantité         2511  Blé et produits
# 4         5301  Disponibilité intérieure         2511  Blé et produits
#
#   Code année Année               Unité Valeur Symbole Description du Symbole
# 0       2017  2017  Milliers de tonnes   4281       S  Données standardisées
# 1       2017  2017  Milliers de tonnes   2302       S  Données standardisées
# 2       2017  2017  Milliers de tonnes   -119       S  Données standardisées
# 3       2017  2017  Milliers de tonnes      0       S  Données standardisées
# 4       2017  2017  Milliers de tonnes   6701       S  Données standardisées

# %%
#Convertir colonne des valeurs en float
dispo['Valeur'] = dispo['Valeur'].astype(float)

# %%
#Multiplier colonne valeurs x1000 car exprimeé en milliers de tonnes
dispo['Valeur'] = dispo['Valeur']*1000

# %%
dispo.head()
# Out:
#   Code Domaine                      Domaine Code zone         Zone  \
# 0          FBS  Nouveaux Bilans Alimentaire         2  Afghanistan
# 1          FBS  Nouveaux Bilans Alimentaire         2  Afghanistan
# 2          FBS  Nouveaux Bilans Alimentaire         2  Afghanistan
# 3          FBS  Nouveaux Bilans Alimentaire         2  Afghanistan
# 4          FBS  Nouveaux Bilans Alimentaire         2  Afghanistan
#
#   Code Élément                   Élément Code Produit          Produit  \
# 0         5511                Production         2511  Blé et produits
# 1         5611   Importations - Quantité         2511  Blé et produits
# 2         5072        Variation de stock         2511  Blé et produits
# 3         5911   Exportations - Quantité         2511  Blé et produits
# 4         5301  Disponibilité intérieure         2511  Blé et produits
#
#   Code année Année               Unité     Valeur Symbole  \
# 0       2017  2017  Milliers de tonnes  4281000.0       S
# 1       2017  2017  Milliers de tonnes  2302000.0       S
# 2       2017  2017  Milliers de tonnes  -119000.0       S
# 3       2017  2017  Milliers de tonnes        0.0       S
# 4       2017  2017  Milliers de tonnes  6701000.0       S
#
#   Description du Symbole
# 0  Données standardisées
# 1  Données standardisées
# 2  Données standardisées
# 3  Données standardisées
# 4  Données standardisées

# %%
# je vais faire un pivot table pour avoir mes élément en colonne
dispo_pivot = dispo.pivot_table(index='Zone', columns='Élément', values='Valeur', aggfunc='sum')
dispo_pivot = dispo_pivot.fillna(value=0)

# %%
dispo_pivot.to_csv("../data/clean_data/diapo_alimentaire.csv", sep=",")
dispo_pivot
# Out:
# Élément                Alimentation pour touristes  Aliments pour animaux  \
# Zone
# Afghanistan                                    0.0               456000.0
# Afrique du Sud                                 0.0              9371000.0
# Albanie                                        0.0               697000.0
# Algérie                                        0.0              4884000.0
# Allemagne                                      0.0             30904000.0
# ...                                            ...                    ...
# Émirats arabes unis                            0.0              1479000.0
# Équateur                                       0.0              1017000.0
# États-Unis d'Amérique                          0.0            151389000.0
# Éthiopie                                       0.0              4710000.0
# Îles Salomon                              182000.0                15000.0
#
# Élément                Autres utilisations (non alimentaire)  \
# Zone
# Afghanistan                                          94000.0
# Afrique du Sud                                     1448000.0
# Albanie                                             177000.0
# Algérie                                            2405000.0
# Allemagne                                          8316000.0
# ...                                                      ...
# Émirats arabes unis                                2661000.0
# Équateur                                           2475000.0
# États-Unis d'Amérique                            171964000.0
# Éthiopie                                           4126000.0
# Îles Salomon                                         11000.0
#
# Élément                Disponibilité alimentaire (Kcal/personne/jour)  \
# Zone
# Afghanistan                                                 1997000.0
# Afrique du Sud                                              2987000.0
# Albanie                                                     3400000.0
# Algérie                                                     3345000.0
# Allemagne                                                   3559000.0
# ...                                                               ...
# Émirats arabes unis                                         3370000.0
# Équateur                                                    2585000.0
# États-Unis d'Amérique                                       3762000.0
# Éthiopie                                                    2304000.0
# Îles Salomon                                                2410000.0
#
# Élément                Disponibilité alimentaire en quantité (kg/personne/an)  \
# Zone
# Afghanistan                                                     357310.0
# Afrique du Sud                                                  556420.0
# Albanie                                                        1260490.0
# Algérie                                                         798710.0
# Allemagne                                                       943240.0
# ...                                                                  ...
# Émirats arabes unis                                             627670.0
# Équateur                                                        563620.0
# États-Unis d'Amérique                                           990380.0
# Éthiopie                                                        361770.0
# Îles Salomon                                                    659790.0
#
# Élément                Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Zone
# Afghanistan                                                      30630.0
# Afrique du Sud                                                   81920.0
# Albanie                                                         117570.0
# Algérie                                                          79620.0
# Allemagne                                                       147960.0
# ...                                                                  ...
# Émirats arabes unis                                              89310.0
# Équateur                                                         89240.0
# États-Unis d'Amérique                                           167000.0
# Éthiopie                                                         26800.0
# Îles Salomon                                                     50950.0
#
# Élément                Disponibilité de protéines en quantité (g/personne/jour)  \
# Zone
# Afghanistan                                                      54090.0
# Afrique du Sud                                                   83360.0
# Albanie                                                         119500.0
# Algérie                                                          92850.0
# Allemagne                                                       104070.0
# ...                                                                  ...
# Émirats arabes unis                                             107260.0
# Équateur                                                         65770.0
# États-Unis d'Amérique                                           113610.0
# Éthiopie                                                         65640.0
# Îles Salomon                                                     53640.0
#
# Élément                Disponibilité intérieure  Exportations - Quantité  \
# Zone
# Afghanistan                          15139000.0                 601000.0
# Afrique du Sud                       66840000.0               10968000.0
# Albanie                               4879000.0                 156000.0
# Algérie                              45365000.0                 743000.0
# Allemagne                           174960000.0               58793000.0
# ...                                         ...                      ...
# Émirats arabes unis                  11795000.0                4914000.0
# Équateur                             23810000.0                8897000.0
# États-Unis d'Amérique               849821000.0              207278000.0
# Éthiopie                             55860000.0                1259000.0
# Îles Salomon                           989000.0                 164000.0
#
# Élément                Importations - Quantité   Nourriture      Pertes  \
# Zone
# Afghanistan                          4555000.0   12968000.0   1146000.0
# Afrique du Sud                       9020000.0   31726000.0   3108000.0
# Albanie                               884000.0    3631000.0    321000.0
# Algérie                             19718000.0   33056000.0   3683000.0
# Allemagne                           66550000.0   77988000.0   5756000.0
# ...                                        ...          ...         ...
# Émirats arabes unis                 14986000.0    5958000.0    525000.0
# Équateur                             2134000.0    9465000.0    860000.0
# États-Unis d'Amérique               84507000.0  322036000.0  36551000.0
# Éthiopie                             2967000.0   38502000.0   2915000.0
# Îles Salomon                          124000.0     419000.0     54000.0
#
# Élément                 Production    Résidus    Semences   Traitement  \
# Zone
# Afghanistan             11609000.0  -111000.0    470000.0     115000.0
# Afrique du Sud          68455000.0  -594000.0    212000.0   21564000.0
# Albanie                  4231000.0  -115000.0     53000.0     113000.0
# Algérie                 26763000.0   -22000.0    358000.0     993000.0
# Allemagne              167828000.0  -831000.0   1712000.0   51109000.0
# ...                            ...        ...         ...          ...
# Émirats arabes unis      1793000.0    94000.0      6000.0    1068000.0
# Équateur                30843000.0  -102000.0    140000.0    9955000.0
# États-Unis d'Amérique  974034000.0  2576000.0  12380000.0  152924000.0
# Éthiopie                52164000.0    -6000.0   1038000.0    4577000.0
# Îles Salomon             1059000.0    -3000.0         0.0     309000.0
#
# Élément                Variation de stock
# Zone
# Afghanistan                      426000.0
# Afrique du Sud                  -322000.0
# Albanie                           72000.0
# Algérie                          374000.0
# Allemagne                        651000.0
# ...                                   ...
# Émirats arabes unis               95000.0
# Équateur                         377000.0
# États-Unis d'Amérique           1454000.0
# Éthiopie                       -1983000.0
# Îles Salomon                      31000.0
#
# [174 rows x 17 columns]

# %%
scaler = StandardScaler()
dispo_pivot_scaled = scaler.fit_transform(dispo_pivot)

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(dispo_pivot_scaled)

# %%
print("Variance expliquée par chaque composante :", pca.explained_variance_ratio_)
# Out:
# Variance expliquée par chaque composante : [0.46595323 0.20021609]

# %%
plt.scatter(principal_components[:, 0], principal_components[:, 1])
plt.xlabel('Première Composante Principale')
plt.ylabel('Deuxième Composante Principale')
plt.title('ACP')
plt.show()

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.46595323 0.20021609]
